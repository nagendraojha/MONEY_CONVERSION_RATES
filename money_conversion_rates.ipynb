# %%
from bs4 import BeautifulSoup
import requests as req

currencies = []

page = req.get('https://www.x-rates.com/').text

soup = BeautifulSoup(page, 'html.parser')

options = soup.find_all('option')[:-11]

for option in options:
    currency_short = option.text[:(option.text.find(" "))]
    currency_name = option.text[(option.text.find(" ") + 3):]
    current_element = {'name': currency_name, 'short': currency_short}
    currencies.append(current_element)
    print('{}. {} ({})'.format(len(currencies), current_element['name'],
                               current_element['short']))

currency_index = int(input('Enter your currency\'s position number: ')) - 1
currency = currencies[currency_index]
amount = input(
    '\033cEnter amount of {}s (if amount isn\'t integer, then write it with a dot, not comma): '
    .format(currency['name'].lower()))


print()
print()
print()
print()
print()
print()

currencies_table_url = 'https://www.x-rates.com/table/?from={}&amount={}'.format(
    currency['short'], amount)

currencies_table_page = req.get(currencies_table_url).text

soup = BeautifulSoup(currencies_table_page, 'html.parser')

table_rows = soup.findChild('table', attrs={
    'class': 'tablesorter'
}).findChildren('tr')[1:]

print('\033cFor {} {}s you\'ll get:'.format(amount, currency['name'].lower()))

for table_row in table_rows:
    row_data = table_row.findChildren('td')
    exchange_rate = {
        'currency': row_data[0].text,
        'amount': float(row_data[1].text)
    }
    print('{:.3f} {}s'.format(exchange_rate['amount'],
                              exchange_rate['currency']))
# Out:
# 1. Australian Dollar (AUD)
# 2. Canadian Dollar (CAD)
# 3. Swiss Franc (CHF)
# 4. Chinese Yuan Renminbi (CNY)
# 5. Danish Krone (DKK)
# 6. Euro (EUR)
# 7. British Pound (GBP)
# 8. Hong Kong Dollar (HKD)
# 9. Hungarian Forint (HUF)
# 10. Indian Rupee (INR)
# 11. Japanese Yen (JPY)
# 12. Mexican Peso (MXN)
# 13. Malaysian Ringgit (MYR)
# 14. Norwegian Krone (NOK)
# 15. New Zealand Dollar (NZD)
# 16. Philippine Peso (PHP)
# 17. Russian Ruble (RUB)
# 18. Swedish Krona (SEK)
# 19. Singapore Dollar (SGD)
# 20. Thai Baht (THB)
# 21. Turkish Lira (TRY)
# 22. US Dollar (USD)
# 23. South African Rand (ZAR)
# 24. Australian Dollar (AUD)
# 25. Canadian Dollar (CAD)
# 26. Swiss Franc (CHF)
# 27. Chinese Yuan Renminbi (CNY)
# 28. Danish Krone (DKK)
# 29. Euro (EUR)
# 30. British Pound (GBP)
# 31. Hong Kong Dollar (HKD)
# 32. Hungarian Forint (HUF)
# 33. Indian Rupee (INR)
# 34. Japanese Yen (JPY)
# 35. Mexican Peso (MXN)
# 36. Malaysian Ringgit (MYR)
# 37. Norwegian Krone (NOK)
# 38. New Zealand Dollar (NZD)
# 39. Philippine Peso (PHP)
# 40. Russian Ruble (RUB)
# 41. Swedish Krona (SEK)
# 42. Singapore Dollar (SGD)
# 43. Thai Baht (THB)
# 44. Turkish Lira (TRY)
# 45. US Dollar (USD)
# 46. South African Rand (ZAR)
# Enter your currency's position number:  10
# cEnter amount of indian rupees (if amount isn't integer, then write it with a dot, not comma):  10000
# cFor 10000 indian rupees you'll get:
# 139881.380 Argentine Pesos
# 183.356 Australian Dollars
# 43.845 Bahraini Dinars
# 1622.951 Botswana Pulas
# 686.546 Brazilian Reals
# 153.765 Bruneian Dollars
# 202.135 Bulgarian Levs
# 162.641 Canadian Dollars
# 112887.365 Chilean Pesos
# 853.041 Chinese Yuan Renminbis
# 506477.106 Colombian Pesos
# 2591.054 Czech Korunas
# 771.421 Danish Krones
# 103.350 Euros
# 904.608 Hong Kong Dollars
# 42184.974 Hungarian Forints
# 15016.958 Icelandic Kronas
# 1961642.497 Indonesian Rupiahs
# 4907124.838 Iranian Rials
# 429.287 Israeli Shekels
# 16694.666 Japanese Yens
# 60425.444 Kazakhstani Tenges
# 166168.489 South Korean Wons
# 35.777 Kuwaiti Dinars
# 646.880 Libyan Dinars
# 514.565 Malaysian Ringgits
# 5256.487 Mauritian Rupees
# 2329.292 Mexican Pesos
# 16007.500 Nepalese Rupees
# 197.126 New Zealand Dollars
# 1238.807 Norwegian Krones
# 44.892 Omani Rials
# 32722.304 Pakistani Rupees
# 6614.851 Philippine Pesos
# 443.521 Polish Zlotys
# 424.455 Qatari Riyals
# 514.466 Romanian New Leus
# 9623.952 Russian Rubles
# 437.281 Saudi Arabian Riyals
# 153.765 Singapore Dollars
# 2216.832 South African Rands
# 34810.971 Sri Lankan Rupees
# 1150.455 Swedish Kronas
# 95.722 Swiss Francs
# 3787.037 Taiwan New Dollars
# 3916.142 Thai Bahts
# 791.591 Trinidadian Dollars
# 4442.679 Turkish Liras
# 428.244 Emirati Dirhams
# 88.218 British Pounds
# 116.608 US Dollars
